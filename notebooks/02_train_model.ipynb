# %% [markdown]
# # Best practice: Set root directory to the root of the project

# %%
# %load_ext autoreload
# %autoreload 2
from constants import ROOT_DIR
import os
import sys
if ROOT_DIR not in sys.path:
    sys.path.append(ROOT_DIR)
os.chdir(ROOT_DIR)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load Imports and Configs

# %%
from configs.data_config import DataConfig
from configs.model_config import ModelConfig
from src.models.lgbm.train import TrainingEngine
from configs.lgbm_config import LGBMConfig
from torchmetrics.retrieval import RetrievalNormalizedDCG

import pandas as pd

data_config = DataConfig()
lgbm_config = LGBMConfig()

# %% [markdown]
# # Read Processed Features Data

# %%
train = pd.read_parquet(data_config.train.file_path)
val = pd.read_parquet(data_config.val.file_path)
test = pd.read_parquet(data_config.test.file_path)

# %% [markdown]
# # Training Engine

# %%
trainer = TrainingEngine(
    train,
    val,
    lgbm_config,
    scorer=RetrievalNormalizedDCG(top_k=5),
    scorer_name="ndcg_at_5"
)

# %% [markdown]
# # Default model benchmark

# %%
trainer.train_default_model()

# %% [markdown]
# # HyperParameter Tuning

# %%
trainer.hyperparameter_tuning()
trainer.best_model_results
# Out:
# 2025-05-04 21:21:43.345 | INFO     | src.models.lgbm.train:hyperparameter_tuning:8 - Experiment 'LGBMRanker_Optimization' already exists.
# [I 2025-05-04 21:21:43,354] A new study created in memory with name: no-name-1b4bf9bc-3ce3-42cf-b058-a640e2f71b24
# 2025-05-04 21:21:43.355 | INFO     | src.models.lgbm.train:optimize_optuna:195 - Optimizing for 20 trials
# [I 2025-05-04 21:22:05,058] Trial 0 finished with value: 0.4914098381996155 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 31, 'max_depth': 7, 'learning_rate': 0.05439233114768742, 'min_split_gain': 0.023649554341539147, 'min_child_weight': 0.07462654854337827, 'min_child_samples': 81, 'subsample': 0.8009008355252296, 'subsample_freq': 0, 'colsample_bytree': 0.6441867562656824, 'reg_alpha': 5.6713028829205345e-06, 'reg_lambda': 1.254441414644514e-06, 'objective': 'rank_xendcg'}. Best is trial 0 with value: 0.4914098381996155.
# [I 2025-05-04 21:22:28,013] Trial 1 finished with value: 0.4914098381996155 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 45, 'max_depth': 3, 'learning_rate': 0.012185504577249309, 'min_split_gain': 0.02296568125306442, 'min_child_weight': 0.006147144830779349, 'min_child_samples': 22, 'subsample': 0.9715897151482813, 'subsample_freq': 10, 'colsample_bytree': 0.8142376591358584, 'reg_alpha': 0.14696161723183468, 'reg_lambda': 1.2440772240726371e-06, 'objective': 'rank_xendcg'}. Best is trial 0 with value: 0.4914098381996155.
# [I 2025-05-04 21:22:53,078] Trial 2 finished with value: 0.4914098381996155 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 48, 'max_depth': 6, 'learning_rate': 0.014551951673365131, 'min_split_gain': 0.14678805877084322, 'min_child_weight': 0.006737004648835344, 'min_child_samples': 80, 'subsample': 0.8048000507116339, 'subsample_freq': 1, 'colsample_bytree': 0.8235379620192573, 'reg_alpha': 0.001558629928399201, 'reg_lambda': 0.00013612968748573625, 'objective': 'lambdarank'}. Best is trial 0 with value: 0.4914098381996155.
# [I 2025-05-04 21:23:22,617] Trial 3 finished with value: 0.4914098381996155 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 31, 'max_depth': 8, 'learning_rate': 0.07924738292583759, 'min_split_gain': 0.1503602746779394, 'min_child_weight': 0.005759396672828399, 'min_child_samples': 36, 'subsample': 0.5927369457756536, 'subsample_freq': 4, 'colsample_bytree': 0.6585826015355712, 'reg_alpha': 0.5972378131900994, 'reg_lambda': 0.0004994553633320239, 'objective': 'rank_xendcg'}. Best is trial 0 with value: 0.4914098381996155.
# [I 2025-05-04 21:23:51,701] Trial 4 finished with value: 0.4914098381996155 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 45, 'max_depth': 5, 'learning_rate': 0.044137057293261665, 'min_split_gain': 0.002099980503438892, 'min_child_weight': 0.005872012374493088, 'min_child_samples': 10, 'subsample': 0.7931251037870921, 'subsample_freq': 5, 'colsample_bytree': 0.8514815661996775, 'reg_alpha': 4.7958483707935596e-08, 'reg_lambda': 0.0001101654740981841, 'objective': 'lambdarank'}. Best is trial 0 with value: 0.4914098381996155.
# [I 2025-05-04 21:24:22,060] Trial 5 finished with value: 0.5705082416534424 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 21, 'max_depth': 3, 'learning_rate': 0.25593742157051247, 'min_split_gain': 0.16947752860413126, 'min_child_weight': 0.01691862878163743, 'min_child_samples': 52, 'subsample': 0.8347425444347243, 'subsample_freq': 4, 'colsample_bytree': 0.9556466717622325, 'reg_alpha': 0.14051325428410566, 'reg_lambda': 0.014098426402362314, 'objective': 'lambdarank'}. Best is trial 5 with value: 0.5705082416534424.
# [I 2025-05-04 21:24:54,381] Trial 6 finished with value: 0.4914098381996155 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 48, 'max_depth': 10, 'learning_rate': 0.23217393187046093, 'min_split_gain': 0.10257740663473161, 'min_child_weight': 0.004140767442080968, 'min_child_samples': 12, 'subsample': 0.8247885662849093, 'subsample_freq': 7, 'colsample_bytree': 0.7936758325047368, 'reg_alpha': 0.5798684164189133, 'reg_lambda': 1.961971245023809e-05, 'objective': 'lambdarank'}. Best is trial 5 with value: 0.5705082416534424.
# [I 2025-05-04 21:25:17,599] Trial 7 finished with value: 0.4914098381996155 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 21, 'max_depth': 4, 'learning_rate': 0.13909785169324979, 'min_split_gain': 0.08606426510760257, 'min_child_weight': 0.012302138120914696, 'min_child_samples': 77, 'subsample': 0.6440774210909357, 'subsample_freq': 8, 'colsample_bytree': 0.5161699507380478, 'reg_alpha': 1.989530534752217e-08, 'reg_lambda': 0.0001419111198981334, 'objective': 'rank_xendcg'}. Best is trial 5 with value: 0.5705082416534424.
# [I 2025-05-04 21:25:55,268] Trial 8 finished with value: 0.5699814558029175 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 49, 'max_depth': 7, 'learning_rate': 0.041053135672385145, 'min_split_gain': 0.19262378484172799, 'min_child_weight': 0.030883659506551257, 'min_child_samples': 54, 'subsample': 0.9784705762619308, 'subsample_freq': 7, 'colsample_bytree': 0.898435397671091, 'reg_alpha': 1.4897528479286743e-07, 'reg_lambda': 9.285421588452652e-06, 'objective': 'lambdarank'}. Best is trial 5 with value: 0.5705082416534424.
# [I 2025-05-04 21:26:21,281] Trial 9 finished with value: 0.4914098381996155 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 50, 'max_depth': 2, 'learning_rate': 0.22106935880067904, 'min_split_gain': 0.0857385045731006, 'min_child_weight': 0.004015795541337703, 'min_child_samples': 37, 'subsample': 0.8753516422617822, 'subsample_freq': 4, 'colsample_bytree': 0.625219808404535, 'reg_alpha': 2.775099740528209, 'reg_lambda': 0.16655689666031198, 'objective': 'rank_xendcg'}. Best is trial 5 with value: 0.5705082416534424.
# [I 2025-05-04 21:26:43,804] Trial 10 finished with value: 0.5581867098808289 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 21, 'max_depth': 2, 'learning_rate': 0.10648565769339297, 'min_split_gain': 0.18648237671381035, 'min_child_weight': 0.001360702696420108, 'min_child_samples': 61, 'subsample': 0.6755450789607245, 'subsample_freq': 2, 'colsample_bytree': 0.9965901494947411, 'reg_alpha': 0.0033207904949614626, 'reg_lambda': 5.521879542388814, 'objective': 'lambdarank'}. Best is trial 5 with value: 0.5705082416534424.
# [I 2025-05-04 21:27:21,597] Trial 11 finished with value: 0.5660273432731628 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 38, 'max_depth': 9, 'learning_rate': 0.02851812728087061, 'min_split_gain': 0.1960848873653919, 'min_child_weight': 0.029702224242371775, 'min_child_samples': 56, 'subsample': 0.9991271857538441, 'subsample_freq': 7, 'colsample_bytree': 0.9625021547805626, 'reg_alpha': 2.4789167939101982e-05, 'reg_lambda': 2.1775380100210308e-08, 'objective': 'lambdarank'}. Best is trial 5 with value: 0.5705082416534424.
# [I 2025-05-04 21:27:56,174] Trial 12 finished with value: 0.571871280670166 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 35, 'max_depth': 6, 'learning_rate': 0.025166443788427605, 'min_split_gain': 0.15882572337851592, 'min_child_weight': 0.025967563187618368, 'min_child_samples': 44, 'subsample': 0.9020391176697196, 'subsample_freq': 3, 'colsample_bytree': 0.9022319047373699, 'reg_alpha': 2.929822660911005e-06, 'reg_lambda': 0.00786507480682545, 'objective': 'lambdarank'}. Best is trial 12 with value: 0.571871280670166.
# [I 2025-05-04 21:28:26,970] Trial 13 finished with value: 0.5706704258918762 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 27, 'max_depth': 4, 'learning_rate': 0.02163468116810699, 'min_split_gain': 0.13885278696210523, 'min_child_weight': 0.018987029341895962, 'min_child_samples': 98, 'subsample': 0.9142518751211909, 'subsample_freq': 3, 'colsample_bytree': 0.9331768814169249, 'reg_alpha': 0.022861365959281173, 'reg_lambda': 0.006131583943704602, 'objective': 'lambdarank'}. Best is trial 12 with value: 0.571871280670166.
# [I 2025-05-04 21:28:57,647] Trial 14 finished with value: 0.571880042552948 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 27, 'max_depth': 5, 'learning_rate': 0.02254600502097467, 'min_split_gain': 0.12594431054550015, 'min_child_weight': 0.07738437160628263, 'min_child_samples': 99, 'subsample': 0.9078810742316902, 'subsample_freq': 2, 'colsample_bytree': 0.8994751775136757, 'reg_alpha': 4.937549440456608e-05, 'reg_lambda': 0.030666888363711564, 'objective': 'lambdarank'}. Best is trial 14 with value: 0.571880042552948.
# [I 2025-05-04 21:29:28,415] Trial 15 finished with value: 0.4914098381996155 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 38, 'max_depth': 6, 'learning_rate': 0.020869213749048394, 'min_split_gain': 0.11579001307896714, 'min_child_weight': 0.07848440932317878, 'min_child_samples': 94, 'subsample': 0.72306519315321, 'subsample_freq': 2, 'colsample_bytree': 0.7347550197386631, 'reg_alpha': 2.5617130798802205e-05, 'reg_lambda': 0.18695164710017603, 'objective': 'lambdarank'}. Best is trial 14 with value: 0.571880042552948.
# [I 2025-05-04 21:29:58,631] Trial 16 finished with value: 0.5652555227279663 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 27, 'max_depth': 5, 'learning_rate': 0.031739355852734775, 'min_split_gain': 0.12407725516580954, 'min_child_weight': 0.049895993258215844, 'min_child_samples': 40, 'subsample': 0.8973063394652483, 'subsample_freq': 0, 'colsample_bytree': 0.8893771596947453, 'reg_alpha': 1.5237067557000708e-06, 'reg_lambda': 7.12943415250951, 'objective': 'lambdarank'}. Best is trial 14 with value: 0.571880042552948.
# [I 2025-05-04 21:30:30,670] Trial 17 finished with value: 0.4914098381996155 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 35, 'max_depth': 7, 'learning_rate': 0.016697687084012477, 'min_split_gain': 0.06289146505668257, 'min_child_weight': 0.04005382300268714, 'min_child_samples': 69, 'subsample': 0.9166627967229336, 'subsample_freq': 2, 'colsample_bytree': 0.752904933327075, 'reg_alpha': 0.00020187411088919485, 'reg_lambda': 0.005778112180003323, 'objective': 'lambdarank'}. Best is trial 14 with value: 0.571880042552948.
# [I 2025-05-04 21:31:05,337] Trial 18 finished with value: 0.5720005035400391 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 26, 'max_depth': 5, 'learning_rate': 0.030357504599860148, 'min_split_gain': 0.15953621062706036, 'min_child_weight': 0.08729513441426284, 'min_child_samples': 44, 'subsample': 0.5243641316553609, 'subsample_freq': 5, 'colsample_bytree': 0.8775594105212166, 'reg_alpha': 3.167367447513567e-07, 'reg_lambda': 0.1740854424091086, 'objective': 'lambdarank'}. Best is trial 18 with value: 0.5720005035400391.
# [I 2025-05-04 21:31:29,102] Trial 19 finished with value: 0.4914098381996155 and parameters: {'boosting_type': 'gbdt', 'num_leaves': 25, 'max_depth': 4, 'learning_rate': 0.010287012897435567, 'min_split_gain': 0.12813155195209383, 'min_child_weight': 0.09827581536952323, 'min_child_samples': 28, 'subsample': 0.5188933928715564, 'subsample_freq': 6, 'colsample_bytree': 0.7253492651165113, 'reg_alpha': 0.00018398266482427854, 'reg_lambda': 0.2132127790400444, 'objective': 'lambdarank'}. Best is trial 18 with value: 0.5720005035400391.
# 2025-05-04 21:32:14.063 | INFO     | src.models.lgbm.train:hyperparameter_tuning:31 - Best ndcg_at_5: 0.5720
# 2025-05-04 21:32:14.064 | INFO     | src.models.lgbm.train:hyperparameter_tuning:32 - Final ndcg_at_5: 0.5720
# 2025-05-04 21:32:14.064 | INFO     | src.models.lgbm.train:hyperparameter_tuning:33 - Best parameters: {'best_boosting_type': 'gbdt', 'best_num_leaves': 26, 'best_max_depth': 5, 'best_learning_rate': 0.030357504599860148, 'best_min_split_gain': 0.15953621062706036, 'best_min_child_weight': 0.08729513441426284, 'best_min_child_samples': 44, 'best_subsample': 0.5243641316553609, 'best_subsample_freq': 5, 'best_colsample_bytree': 0.8775594105212166, 'best_reg_alpha': 3.167367447513567e-07, 'best_reg_lambda': 0.1740854424091086, 'best_objective': 'lambdarank', 'best_iteration': 44}
#    k    ndcg@k  recall@k  precision@k     map@k
# 0  1  0.232716  0.231987     0.231987  0.231987
# 1  2  0.366093  0.446801     0.220623  0.336616
# 2  3  0.458702  0.632997     0.208025  0.397559
# 3  4  0.523403  0.781818     0.193645  0.435185
# 4  5  0.572001  0.906397     0.180337  0.460606

# %% [markdown]
# # Train Best Model with full data

# %%
trainer.train_best_model()

# %% [markdown]
# # Save best and default model for benchmarking

# %%
trainer.save_best_model()
trainer.save_default_model()
